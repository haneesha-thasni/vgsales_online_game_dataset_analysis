# %% [markdown]
# ## Data Description of vgsales_online_game dataset
#
# * Rank: A unique integer identifier that ranks the video games based on a specific criterion (likely sales).
#
# * Name: The name of the video game.
#
# * Platform: The gaming platform on which the video game was released (e.g., PS4, Xbox One, PC).
#
# * Year: The year the game was released. This column has some missing values, with 16,327 non-null entries out of 16,598.
#
# * Genre: The genre of the video game (e.g., Action, Sports, RPG).
#
# * Publisher: The company that published the video game. There are a few missing values, with 16,540 non-null entries.
#
# * NA_Sales: Sales in North America, measured in millions of units.
#
# * EU_Sales: Sales in Europe, measured in millions of units.
#
# * JP_Sales: Sales in Japan, measured in millions of units.
#
# * Other_Sales: Sales in regions other than North America, Europe, and Japan, measured in millions of units.
#
# * Global_Sales: The total global sales of the video game, measured in millions of units.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('vgsales_online_game.csv')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
df.size
# Out:
# 182578

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# ## Information of the dataset
#
# * Columns = 11
# * Rows = 16598
# * Data types
#    - float =6
#    - integer = 1
#    - object = 4
# * Occur Null values
#    - Year = 271
#    - Publisher = 58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.describe().T
# Out:
#                 count         mean          std      min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933     1.00  4151.25  8300.50
# Year          16327.0  2006.406443     5.828981  1980.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683     0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351     0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291     0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588     0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028     0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %%
df.describe(include='all').T
# Out:
#                 count unique                          top  freq         mean  \
# Rank          16598.0    NaN                          NaN   NaN  8300.605254
# Name            16598  11493  Need for Speed: Most Wanted    12          NaN
# Platform        16598     31                           DS  2163          NaN
# Year          16327.0    NaN                          NaN   NaN  2006.406443
# Genre           16598     12                       Action  3316          NaN
# Publisher       16540    578              Electronic Arts  1351          NaN
# NA_Sales      16598.0    NaN                          NaN   NaN     0.264667
# EU_Sales      16598.0    NaN                          NaN   NaN     0.146652
# JP_Sales      16598.0    NaN                          NaN   NaN     0.077782
# Other_Sales   16598.0    NaN                          NaN   NaN     0.048063
# Global_Sales  16598.0    NaN                          NaN   NaN     0.537441
#
# ...

# %%
df.describe(include='object')
# Out:
#                                Name Platform   Genre        Publisher
# count                         16598    16598   16598            16540
# unique                        11493       31      12              578
# top     Need for Speed: Most Wanted       DS  Action  Electronic Arts
# freq                             12     2163    3316             1351

# %%
df.nunique()
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64

# %%
for i in df.columns:
    print(i,':',df[i].unique())
# Out:
# Rank : [    1     2     3 ... 16598 16599 16600]
# Name : ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ... 'Plushees'
#  'Woody Woodpecker in Crazy Castle 5' 'Know How 2']
# Platform : ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# Year : [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2003. 1986. 2000.   nan 1995. 2016. 1991. 1981. 1987.
#  1980. 1983. 2020. 2017.]
# Genre : ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
# Publisher : ['Nintendo' 'Microsoft Game Studios' 'Take-Two Interactive'
#  'Sony Computer Entertainment' 'Activision' 'Ubisoft' 'Bethesda Softworks'
# ...

# %%
df.value_counts().sum()
# Out:
# 16291

# %%
df['Platform'].value_counts()
# Out:
# Platform
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %% [markdown]
# ## Coverting data type
#  * Year (float) - int

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df['Year'].values
# Out:
# array([2006., 1985., 2008., ..., 2008., 2010., 2003.])

# %%
df.dropna(subset=['Year'],inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       36
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %%
df['Year']=df['Year'].astype('int64')

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# ## Checking Duplicates

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Length: 16327, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset=['Rank','Genre']).sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.duplicated(['Name', 'Platform', 'Year', 'Publisher', 'NA_Sales',
       'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']).sum()
# Out:
# 0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Q) calculate the ratio of total sales and store the result in a new column in a DataFrame

# %%
df['Total_sales_ratio']=df['NA_Sales']+df['EU_Sales']+df['JP_Sales']+df['Other_Sales']/100

# %%
df
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %% [markdown]
# ### Q)  calculate the age of games in your dataset based on the release year

# %%
import datetime

# %%
from datetime import datetime

# %%
current_year=datetime.now().year
current_year
# Out:
# 2024

# %%
df['Game_Age']=current_year-df['Year']

# %%
df
# Out:
#         Rank                                         Game_Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %% [markdown]
# ## Drop a Column

# %% [markdown]
# ### Q) remove a specific column from a DataFrame in place, without creating a new DataFrame

# %%
df.drop(columns=['Game_Age'],inplace=True)

# %%
df
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %% [markdown]
# ## rename()

# %%
df.rename(columns={'Name':'Game_Name'},inplace=True)

# %%
df
# Out:
#         Rank                                         Game_Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %% [markdown]
# ## Filter and Sort

# %% [markdown]
# ### Q) Filter games released in a specific year

# %%
releasing_year=df[df['Year']==2015]
releasing_year.reset_index(drop=True,inplace=True)
releasing_year
# Out:
#       Rank                                          Game_Name Platform  Year  \
# 0       34                          Call of Duty: Black Ops 3      PS4  2015
# 1       78                                            FIFA 16      PS4  2015
# 2       93                       Star Wars Battlefront (2015)      PS4  2015
# 3      102                          Call of Duty: Black Ops 3     XOne  2015
# 4      110                                          Fallout 4      PS4  2015
# ..     ...                                                ...      ...   ...
# 609  16502         Irotoridori no Sekai: World's End Re-Birth      PSV  2015
# 610  16531                                  Kiniro no Corda 3      3DS  2015
# 611  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS  2015
# 612  16551                Hakuoki: Reimeiroku - Omouhase Kara      PSV  2015
# 613  16568                                          Teslagrad      PSV  2015
#
# ...

# %% [markdown]
# ### Q) Filter games from a specific genre

# %%
action_genre=df[df['Genre']=='Adventure']
action_genre.reset_index(drop=True,inplace=True)
action_genre
# Out:
#        Rank                           Game_Name Platform  Year      Genre  \
# 0        51  Super Mario Land 2: 6 Golden Coins       GB  1992  Adventure
# 1       159                    Assassin's Creed     X360  2007  Adventure
# 2       219                    Assassin's Creed      PS3  2007  Adventure
# 3       252     Zelda II: The Adventure of Link      NES  1987  Adventure
# 4       401          Rugrats: Search For Reptar       PS  1998  Adventure
# ...     ...                                 ...      ...   ...        ...
# 1271  16575    Scarlett: Nichijou no Kyoukaisen      PS2  2008  Adventure
# 1272  16578               Neo Angelique Special      PSP  2008  Adventure
# 1273  16583                           Real Rode      PS2  2008  Adventure
# 1274  16589      Secret Files 2: Puritas Cordis       DS  2009  Adventure
# 1275  16594                 Myst IV: Revelation       PC  2004  Adventure
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# ### Q) Filter games with Global Sales greater than 50 million units

# %%
high_sale_game=df[df['Global_Sales']>50]
high_sale_game
# Out:
#    Rank   Game_Name Platform  Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales  Total_sales_ratio
# 0      3.77         8.46         82.74            74.3646

# %% [markdown]
# ### Q) filter and sort the vgsales_online_game dataset to find all games released in 2014, displaying their name, platform, publisher, and total sales ratio, sorted by platform in ascending and total_sales_ratio in descending

# %%
year_2010=df.loc[df['Year']==2010][['Game_Name','Platform','Genre','Publisher','Total_sales_ratio']].sort_values(by=['Platform','Total_sales_ratio'],ascending=[True,False])
year_2010.reset_index(drop=True,inplace=True)
year_2010
# Out:
#                                      Game_Name Platform         Genre  \
# 0                  Pokemon Black/Pokemon White       DS  Role-Playing
# 1     Mario vs. Donkey Kong: Mini-Land Mayhem!       DS        Puzzle
# 2                                  Art Academy       DS          Misc
# 3                 LEGO Harry Potter: Years 1-4       DS        Action
# 4                  Toy Story 3: The Video Game       DS        Action
# ...                                        ...      ...           ...
# 1254               W.L.O. Sekai Renai Kikousen     X360     Adventure
# 1255        Sharin no Kuni, Himawari no Shoujo     X360     Adventure
# 1256     Winter Sports 3: The Great Tournament     X360        Sports
# 1257           No Fate! Only the Power of Will     X360     Adventure
# 1258                John Daly's ProStroke Golf     X360        Sports
#
#                                    Publisher  Total_sales_ratio
# ...

# %% [markdown]
# ### Q) Filter games with Global Sales greater than 1 million units

# %%
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
ms_games=df.loc[(df['Publisher']=='Microsoft Game Studios')&(df['Global_Sales']>1)]
ms_games.reset_index(drop=True,inplace=True)
ms_games
# Out:
#     Rank                                Game_Name Platform  Year  \
# 0     16                       Kinect Adventures!     X360  2010
# 1     44                                   Halo 3     X360  2007
# 2     63                              Halo: Reach     X360  2010
# 3     66                                   Halo 4     X360  2012
# 4     73                                Minecraft     X360  2013
# 5     80                                   Halo 2       XB  2004
# 6    119                           Gears of War 2     X360  2008
# 7    130                     Halo: Combat Evolved       XB  2001
# 8    134                             Halo 3: ODST     X360  2009
# 9    140                            Kinect Sports     X360  2010
# 10   141                           Gears of War 3     X360  2011
# 11   142                             Gears of War     X360  2006
# 12   161                       Forza Motorsport 3     X360  2009
# ...

# %% [markdown]
# ### Q)  Retrieve the first six rows of the DataFrame, selecting the columns from 'Game_Name' to 'Publisher', and then sort these rows by the 'Year' column in descending order

# %%
high_rank=df.loc[:5,'Game_Name':'Publisher'].sort_values(by='Year',ascending=False)
high_rank.reset_index(drop=True,inplace=True)
high_rank
# Out:
#                   Game_Name Platform  Year         Genre Publisher
# 0         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 1            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 2                Wii Sports      Wii  2006        Sports  Nintendo
# 3  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
# 4                    Tetris       GB  1989        Puzzle  Nintendo
# 5         Super Mario Bros.      NES  1985      Platform  Nintendo

# %% [markdown]
# ### Q) Select specific rows and columns by index

# %%
middle=df.iloc[100:500,6:]
middle.reset_index(drop=True,inplace=True)
middle
# Out:
#      NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0        3.83      2.19      0.60         0.70          7.31
# 1        4.52      2.09      0.01         0.67          7.30
# 2        3.51      3.03      0.00         0.73          7.27
# 3        2.85      2.93      0.35         1.10          7.23
# 4        3.27      2.83      0.08         1.02          7.20
# ..        ...       ...       ...          ...           ...
# 395      0.99      0.32      1.38         0.20          2.89
# 396      1.51      1.12      0.01         0.24          2.89
# 397      1.54      1.07      0.00         0.28          2.88
# 398      2.03      0.72      0.02         0.11          2.88
# 399      1.30      1.27      0.00         0.31          2.88
#
#      Total_sales_ratio
# 0               6.6270
# 1               6.6267
# 2               6.5473
# 3               6.1410
# 4               6.1902
# ..                 ...
# 395             2.6920
# 396             2.6424
# ...

# %% [markdown]
# ### Q) Select the last row

# %%
last_row=df.iloc[-1]
last_row
# Out:
# Rank                            16600
# Game_Name            Spirits & Spells
# Platform                          GBA
# Year                             2003
# Genre                        Platform
# Publisher                     Wanadoo
# NA_Sales                         0.01
# EU_Sales                          0.0
# JP_Sales                          0.0
# Other_Sales                       0.0
# Global_Sales                     0.01
# Total_sales_ratio                0.01
# Name: 16597, dtype: object

# %% [markdown]
# ## Example of Combination of loc and iloc
# ### Q) Filter Action games and then select the first 5 rows of specific columns ['Name', 'Global_Sales']

# %%
action=df.loc[df['Genre']=='Action',['Game_Name','Global_Sales']].iloc[:5]
action.reset_index(drop=True,inplace=True)
action
# Out:
#                        Game_Name  Global_Sales
# 0             Grand Theft Auto V         21.40
# 1  Grand Theft Auto: San Andreas         20.81
# 2             Grand Theft Auto V         16.38
# 3    Grand Theft Auto: Vice City         16.15
# 4           Grand Theft Auto III         13.10

# %% [markdown]
# ### Q) Filter games released in 2010 and belonging to the racing genre

# %%
racing=df[(df['Year']==2010)&(df['Genre']=='Racing')]
racing.reset_index(drop=True,inplace=True)
racing
# Out:
#      Rank                                         Game_Name Platform  Year  \
# 0      55                                    Gran Turismo 5      PS3  2010
# 1     523                       Need for Speed: Hot Pursuit      PS3  2010
# 2     731                       Need for Speed: Hot Pursuit     X360  2010
# 3    1244                     Sonic & Sega All-Stars Racing      Wii  2010
# 4    1341                                   Kinect Joy Ride     X360  2010
# 5    1438                                           F1 2010      PS3  2010
# 6    1804                                  ModNation Racers      PS3  2010
# 7    1890                     Sonic & Sega All-Stars Racing       DS  2010
# 8    1894                                 Sonic Free Riders     X360  2010
# 9    2112                     Sonic & Sega All-Stars Racing      PS3  2010
# 10   2347                                           F1 2010     X360  2010
# ...

# %% [markdown]
# ### Q) Filter games with Global Sales over 10 million units in either Europe or Japan

# %%
eu_jp=df[(df['EU_Sales']>10)|(df['JP_Sales']>10)]
eu_jp.reset_index(drop=True,inplace=True)
eu_jp
# Out:
#    Rank                 Game_Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 2     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 3     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
# 4    11                Nintendogs       DS  2005    Simulation  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Total_sales_ratio
# 0     41.49     29.02      3.77         8.46         82.74            74.3646
# 1     15.85     12.88      3.79         3.31         35.82            32.5531
# 2     15.75     11.01      3.28         2.96         33.00            30.0696
# 3     11.27      8.89     10.22         1.00         31.37            30.3900
# 4      9.07     11.00      1.93         2.75         24.76            22.0275

# %%
df['Game_Name'].values
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'SCORE International Baja 1000: The Official Game', 'Know How 2',
#        'Spirits & Spells'], dtype=object)

# %% [markdown]
# ### Q) filter the vgsales_online_game dataset to find all games with 'Kids' in their title

# %%
kids=df[df['Game_Name'].str.contains('Kids')]
kids
# Out:
#         Rank                                          Game_Name Platform  \
# 682      684                                    Just Dance Kids      Wii
# 4407    4409                      Discovery Kids: Kitten Corner       DS
# 4761    4763                                  Just Dance Kids 2     X360
# 5534    5536                            Spy Kids 3-D: Game Over      GBA
# 5566    5568                     Discovery Kids: Puppy Playtime       DS
# 5955    5957                                  Just Dance Kids 2      Wii
# 6639    6641                                Spy Kids Challenger      GBA
# 6660    6662                                  Just Dance Kids 2      PS3
# 7021    7023                                Virtua Fighter Kids      SAT
# 7162    7164                  Discovery Kids: Dolphin Discovery       DS
# 7499    7501                      Discovery Kids: Pony Paradise       DS
# 7624    7626                                     Snowboard Kids      N64
# ...

# %% [markdown]
# ### Q) filter the DataFrame to display only the rows where the 'Game_Name' column contains the word 'Women

# %%
women=df[df['Game_Name'].str.contains('Women')]
women.reset_index(drop=True,inplace=True)
women
# Out:
#     Rank                                          Game_Name Platform  Year  \
# 0   4705  James Patterson Women's Murder Club: Games of ...       DS  2009
# 1  14182                    Women's Volleyball Championship      PS2  2007
#
#        Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Adventure       THQ      0.15      0.22      0.00         0.05
# 1     Sports     Spike      0.00      0.00      0.03         0.00
#
#    Global_Sales  Total_sales_ratio
# 0          0.41             0.3705
# 1          0.03             0.0300

# %% [markdown]
# ## isin()
# ### Q) filter the dataset to find all games published by 'Inti Creates', 'Takuyo', 'Interchannel-Holon', or 'Rain Games'

# %%
df['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
games=df[df['Publisher'].isin(['Inti Creates','Takuyo','Interchannel-Holon', 'Rain Games'])]
games.reset_index(drop=True,inplace=True)
games
# Out:
#     Rank                            Game_Name Platform  Year      Genre  \
# 0  16475  Azure Striker Gunvolt: Striker Pack      3DS  2016     Action
# 1  16506                  Shinigami to Shoujo      PSP  2011  Adventure
# 2  16513                      Palais de Reine      PS2  2007   Strategy
# 3  16568                            Teslagrad      PSV  2015   Platform
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0        Inti Creates       0.0      0.00      0.01          0.0
# 1              Takuyo       0.0      0.00      0.01          0.0
# 2  Interchannel-Holon       0.0      0.00      0.01          0.0
# 3          Rain Games       0.0      0.01      0.00          0.0
#
#    Global_Sales  Total_sales_ratio
# 0          0.01               0.01
# 1          0.01               0.01
# 2          0.01               0.01
# 3          0.01               0.01

# %% [markdown]
# ### Q) create a new DataFrame that excludes all rows where the 'Platform' column contains any of the values 'PS', 'PS2', 'PS3', or 'PS4'

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
excluded_platform=['PS','PS2','PS3','PS4']

# %%
other_platform=df[~df['Platform'].isin(excluded_platform)]

# %%
other_platform
# Out:
#         Rank                           Game_Name Platform  Year         Genre  \
# 0          1                          Wii Sports      Wii  2006        Sports
# 1          2                   Super Mario Bros.      NES  1985      Platform
# 2          3                      Mario Kart Wii      Wii  2008        Racing
# 3          4                   Wii Sports Resort      Wii  2009        Sports
# 4          5            Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# ...      ...                                 ...      ...   ...           ...
# 16592  16595                            Plushees       DS  2008    Simulation
# 16593  16596  Woody Woodpecker in Crazy Castle 5      GBA  2002      Platform
# 16594  16597       Men in Black II: Alien Escape       GC  2003       Shooter
# 16596  16599                          Know How 2       DS  2010        Puzzle
# 16597  16600                    Spirits & Spells      GBA  2003      Platform
#
# ...

# %% [markdown]
# ## reset_index()

# %%
kids.reset_index(drop=True,inplace=True)
kids
# Out:
#      Rank                                          Game_Name Platform  Year  \
# 0     684                                    Just Dance Kids      Wii  2010
# 1    4409                      Discovery Kids: Kitten Corner       DS  2009
# 2    4763                                  Just Dance Kids 2     X360  2011
# 3    5536                            Spy Kids 3-D: Game Over      GBA  2003
# 4    5568                     Discovery Kids: Puppy Playtime       DS  2009
# 5    5957                                  Just Dance Kids 2      Wii  2011
# 6    6641                                Spy Kids Challenger      GBA  2002
# 7    6662                                  Just Dance Kids 2      PS3  2011
# 8    7023                                Virtua Fighter Kids      SAT  1995
# 9    7164                  Discovery Kids: Dolphin Discovery       DS  2008
# 10   7501                      Discovery Kids: Pony Paradise       DS  2009
# ...

# %% [markdown]
# ## set_index()

# %%
other_platform.set_index(['Year'])
# Out:
#        Rank                           Game_Name Platform         Genre  \
# Year
# 2006      1                          Wii Sports      Wii        Sports
# 1985      2                   Super Mario Bros.      NES      Platform
# 2008      3                      Mario Kart Wii      Wii        Racing
# 2009      4                   Wii Sports Resort      Wii        Sports
# 1996      5            Pokemon Red/Pokemon Blue       GB  Role-Playing
# ...     ...                                 ...      ...           ...
# 2008  16595                            Plushees       DS    Simulation
# 2002  16596  Woody Woodpecker in Crazy Castle 5      GBA      Platform
# 2003  16597       Men in Black II: Alien Escape       GC       Shooter
# 2010  16599                          Know How 2       DS        Puzzle
# 2003  16600                    Spirits & Spells      GBA      Platform
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# Year
# ...

# %% [markdown]
# ## pivot_table()

# %% [markdown]
# ### Q) create a pivot table that shows the sum of global sales for each genre across different years

# %%
pivot=df.pivot_table(index='Year',columns='Genre',values='Global_Sales',aggfunc='sum')
pivot
# Out:
# Genre  Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# Year
# 1980     0.34        NaN      0.77   2.71       NaN     NaN     NaN
# 1981    14.84        NaN       NaN    NaN      6.93    2.24    0.48
# 1982     6.52        NaN       NaN   0.87      5.03   10.03    1.57
# 1983     2.86       0.40       NaN   2.14      6.93    0.78     NaN
# 1984     1.85        NaN       NaN   1.45      0.69    3.14    5.95
# 1985     3.52        NaN      1.05    NaN     43.17    3.21     NaN
# 1986    13.74        NaN       NaN    NaN      9.39     NaN    1.96
# 1987     1.12       4.38      5.42    NaN      1.74     NaN     NaN
# 1988     1.75        NaN       NaN    NaN     27.73    5.58    2.14
# 1989     4.64        NaN       NaN   1.28     20.66   37.75     NaN
# 1990     6.39        NaN       NaN    NaN     22.97    6.00    6.26
# 1991     6.76       2.24      0.39   0.08      7.64    3.24    1.14
# 1992     3.83      12.24     15.25   4.94     13.42    4.84    9.04
# ...

# %% [markdown]
# ## Remove warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## groupby()

# %% [markdown]
# ### Q) group the dataset by both game name and year, and then calculate the maximum total sales ratio and minimum global sales for each game in each year

# %%
min_max=df.groupby(['Game_Name','Year']).agg({'Total_sales_ratio':max,'Global_Sales':min})
min_max
# Out:
#                                               Total_sales_ratio  Global_Sales
# Game_Name                               Year
# '98 Koshien                             1998             0.3703          0.41
# .hack//G.U. Vol.1//Rebirth              2006             0.1700          0.17
# .hack//G.U. Vol.2//Reminisce            2006             0.2003          0.23
# .hack//G.U. Vol.2//Reminisce (jp sales) 2006             0.1600          0.16
# .hack//G.U. Vol.3//Redemption           2007             0.1700          0.17
# ...                                                         ...           ...
# thinkSMART FAMILY!                      2010             0.0300          0.03
# thinkSMART: Chess for Kids              2011             0.0100          0.01
# uDraw Studio                            2010             2.2520          2.46
# uDraw Studio: Instant Artist            2011             0.1702          0.02
# ...

# %% [markdown]
# ### Q) group the dataset by platform and game name, and then calculate the maximum, minimum, mean, and total North American sales for each combination

# %%
group=df.groupby(['Platform','Game_Name'])['NA_Sales'].agg(['max','min','mean','sum'])
group
# Out:
#                                       max   min  mean   sum
# Platform Game_Name
# 2600     Action Force                0.50  0.50  0.50  0.50
#          Adventures of Tron          0.63  0.63  0.63  0.63
#          Air Raid                    0.72  0.72  0.72  0.72
#          Airlock                     0.36  0.36  0.36  0.36
#          Alien                       0.74  0.74  0.74  0.74
# ...                                   ...   ...   ...   ...
# XOne     Wolfenstein: The Old Blood  0.07  0.07  0.07  0.07
#          XCOM 2                      0.01  0.01  0.01  0.01
#          Zombie Army Trilogy         0.04  0.04  0.04  0.04
#          Zoo Tycoon (2013)           0.18  0.18  0.18  0.18
#          Zumba Fitness: World Party  0.17  0.17  0.17  0.17
#
# [16324 rows x 4 columns]

# %% [markdown]
# ## idxmax()

# %% [markdown]
# ### Q)  Row with the highest global sales in the dataset

# %%
df.loc[df['Global_Sales'].idxmax()]
# Out:
# Rank                          1
# Game_Name            Wii Sports
# Platform                    Wii
# Year                       2006
# Genre                    Sports
# Publisher              Nintendo
# NA_Sales                  41.49
# EU_Sales                  29.02
# JP_Sales                   3.77
# Other_Sales                8.46
# Global_Sales              82.74
# Total_sales_ratio       74.3646
# Name: 0, dtype: object

# %% [markdown]
# ### Q)  Row with the lowest global sales in the dataset

# %%
df.loc[df['Global_Sales'].idxmin()]
# Out:
# Rank                      15983
# Game_Name                 Turok
# Platform                     PC
# Year                       2008
# Genre                    Action
# Publisher            Touchstone
# NA_Sales                    0.0
# EU_Sales                   0.01
# JP_Sales                    0.0
# Other_Sales                 0.0
# Global_Sales               0.01
# Total_sales_ratio          0.01
# Name: 15980, dtype: object

# %% [markdown]
# ### Q) Which game has the highest maximum total sales ratio among all the games in the dataset

# %%
df.groupby(['Game_Name'])['Total_sales_ratio'].max().idxmax()
# Out:
# 'Wii Sports'

# %% [markdown]
# ## cut()

# %% [markdown]
# ### Q) categorize global sales into different ranks such as 'low', 'medium', 'high', and 'very high' based on specific sales ranges

# %%
df['Global_Sales'].max()
# Out:
# 82.74

# %%
df['Global_Sales'].min()
# Out:
# 0.01

# %%
df['Global_Rank_Level']=pd.cut(df['Global_Sales'],bins=[0,20,40,60,df['Global_Sales'].max()],labels=['Low','Medium','High','Very High'])

# %%
df
# Out:
#         Rank                                         Game_Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...
